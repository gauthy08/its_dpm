# %%
import requests

token = 'sk-15b54c10119c45f7a45e790a109d7c8b'
base_url = 'https://chatbot-open-webui.apps.prod.w.oenb.co.at'

url = f'{base_url}/api/v1/knowledge/list'
headers = {
    'Authorization': f'Bearer {token}',
    'Content-Type': 'application/json'
}

response = requests.get(url, headers=headers)
kb_list = response.json()

for kb in kb_list:
    print(f"📚 {kb['name']} (ID: {kb['id']})")
# Out:
# 📚 Datenkatalog (ID: ebed13cd-5967-4acd-a944-a8945051aff0)
# 📚 Berechtigungen (ID: 8950e171-5cb6-42cf-81b3-89faa1e3a913)
# 📚 ITS AI USE CASE (COREP) (ID: aace4dfd-3f4f-46da-9936-b38dc133e3e9)
# 📚 ITS Use Case (ID: 08c5ec92-e537-4dff-b036-302657b11573)
# 📚 Test (ID: e5aaf543-429e-4cfa-88e4-f1eff6c0c923)
# 📚 SDS (ID: 2a2f17ff-60e1-4625-b1cc-dd52aecc2371)
# 📚 START-Systeme (Test-BAAR) (ID: 0ed83ce8-b808-48b7-a56c-99a32276587f)
